# %%
import os
import sys
import matplotlib

project_path = os.path.abspath("..")  
sys.path.append(project_path)
matplotlib.rcParams.update(matplotlib.rcParamsDefault)

# %%
import pyCARM

# %%
import pyCARM.basics as bcs
# Out:
# I
# E
# 5 9 11 12

# %%
import pyCARM.fixed_route as frx
