# %%
import pyCARM.basic as bcs

# %%
GRID_ROWS = 10
GRID_COLS = 10
REENTRY_DEPTH = 2
EXIT_CELLS = [(9, 3), (9, 4), (9, 5), (9,6)],
NUMBER_OF_STEPS = 1000
NUMBER_OF_REPETITIONS = 5

CONFIGS = [
# Define configurations
    {"num_particles": 10, "exclude_rows_above_exit": 3},
    {"num_particles": 20, "exclude_rows_above_exit": 5},
    {"num_particles": 15, "exclude_rows_above_exit": 4}
]

bcs.run_multiple_simulations(
    grid_rows = GRID_ROWS, 
    grid_cols = GRID_COLS, 
    reentry_depth = REENTRY_DEPTH, 
    exit_cells = EXIT_CELLS,
    number_of_steps = NUMBER_OF_STEPS,
    configurations = CONFIGS,
    num_repetitions = NUMBER_OF_REPETITIONS
)
# Out:
# Average flow across repetitions for each configuration:
# Configuration (num_particles=10, exclude_rows_above_exit=3): 0.0090
# Configuration (num_particles=20, exclude_rows_above_exit=5): 0.0121
# Configuration (num_particles=15, exclude_rows_above_exit=4): 0.0091
